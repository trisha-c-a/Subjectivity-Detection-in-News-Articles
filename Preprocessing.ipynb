# %%
# !python -m spacy download en_core_web_sm

# %% [markdown]
# ## Imports

# %%
import pandas as pd
import numpy as np
import os
import random
import string
import re

import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')
nltk.download('punkt')

import spacy
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %% [markdown]
# ## Merging Data
#
# This is done to apply preprocessing to all sequences before dividing them into a train, val and test splits.

# %%
PATH = "path"

# %%
# train = pd.read_csv(os.path.join(PATH,"train.csv"))
# dev = pd.read_csv(os.path.join(PATH,"dev.csv"))

# %%
# data = pd.concat([train,dev])
# data.to_csv(os.path.join(PATH,'merged.csv'), index=False)
data = pd.read_csv(os.path.join(PATH, "merged.csv"))

# %%
data[:100]
# Out:
#                              sentence_id  \
# 0   b9e1635a-72aa-467f-86d6-f56ef09f62c3
# 1   f99b5143-70d2-494a-a2f5-c68f10d09d0a
# 2   4076639c-aa56-4202-ae0f-9d9217f8da68
# 3   b057c366-698e-419d-a284-9b16d835c64e
# 4   a5a9645e-7850-41ba-90a2-5def725cd5b8
# ..                                   ...
# 95  921a1f46-1494-4004-95ed-d26b907d3aae
# 96  c2ca3827-247d-4302-971d-8054d32c73aa
# 97  58d703aa-131b-40b4-8373-0c34b86bb1c7
# 98  cb0dd788-2074-4469-a8f9-24d163db41c6
# 99  84ac387e-d7c7-4cb5-b82d-8a07a2869ce4
#
#                                              sentence label  solved_conflict
# 0   Gone are the days when they led the world in r...  SUBJ             True
# 1   The trend is expected to reverse as soon as ne...   OBJ            False
# 2              But there is the specious point again.   OBJ            False
# 3   He added he wouldn’t be surprised to see a new...   OBJ            False
# 4   Not less government, you see; the same amount ...  SUBJ            False
# ..                                                ...   ...              ...
# 95    It has been a bumpy road even to this juncture.  SUBJ            False
# 96  Socialists believe that, if everyone cannot ha...   OBJ             True
# 97  Vučić said he regretted it but cited a deepeni...   OBJ            False
# 98  “There have been more rightwing extremists spr...   OBJ            False
# 99  –The Exposé  The real problem is that the New ...   OBJ            False
#
# [100 rows x 4 columns]

# %% [markdown]
# ## Preprocessing
#
# The text contains the following that will be changed/removed:
#
#
# *   Capitalization of words, particularly proper nouns.
# *   Punctuation specifically in words like [that's], [I'm], etc.
# *   There are several " ’ " instead of " ' " that need to be changed before removing punctuation
# * Some number are large enough that they are separated by commas. Example: "2,000,000". When removing commas any commas removed from numbers need to be done such that the meaning of the number remains the same. Example: "2,000,000" becomes "2000000" and not "2 000 000"

# %% [markdown]
# ### Change text to lowercase

# %%
def to_lower(phrase):
  return phrase.lower()

# %%
data["sentence"] = data["sentence"].apply(to_lower)

# %% [markdown]
# ### Remove punctuation

# %%
#Remove all punctuation except words that have [']
#Punctuation not removed $, %, -, .
def remove_punc(text):
    # Replace Unicode character ’ with '
    text = re.sub('’', "'", text)

    # Remove commas from numbers without introducing spaces
    text = re.sub(r'(\d),(\d)', r'\1\2', text)

    # Keep $, %, -, . and words with 's; replace other punctuation with spaces
    pattern = r"[^\w\s$%.'\-]"
    return re.sub(pattern, ' ', text)

# %%
data["sentence"] = data["sentence"].apply(remove_punc)

# %% [markdown]
# ### Normalize

# %%
def replacements(text):
    # Substitutes 've with have
    text = re.sub(r"\b(\w+)'ve\b", r"\1 have", text)

    # Substitutes n't with not
    text = re.sub(r"\b(\w+)n't\b", r"\1 not", text)

    # Substitutes 'd with would
    text = re.sub(r"\b(\w+)'d\b", r"\1 would", text)

    # Substitutes 'll with will
    text = re.sub(r"\b(\w+)'ll\b", r"\1 will", text)

    # Substitutes 're with are
    text = re.sub(r"\b(\w+)'re\b", r"\1 are", text)

    # Substitutes 'm with am
    text = re.sub(r"\b(\w+)'m\b", r"\1 am", text)

    return text

# %%
data["sentence"] = data["sentence"].apply(replacements)

# %% [markdown]
# ### Separate $, %, - and . from words/numbers

# %%
def add_spaces(text):
    # Add spaces before and after $, %, -, .
    pattern = r'(\$|%|-|\.)'
    return re.sub(pattern, r' \1 ', text)

# %%
data["sentence"] = data["sentence"].apply(add_spaces)

# %% [markdown]
# ### Apply stemming

# %%
def remove_apostrophe_s(text):
    # Replace 's at the end of words
    return re.sub(r"\b(\w+)'s\b", r"\1", text)

# %%
data["sentence"] = data["sentence"].apply(remove_apostrophe_s)

# %%
for index, row in data.iterrows():
  print(row)
# Out:
# sentence_id                     b9e1635a-72aa-467f-86d6-f56ef09f62c3
# sentence           gone are the days when they led the world in r...
# label                                                           SUBJ
# solved_conflict                                                 True
# Name: 0, dtype: object
# sentence_id                     f99b5143-70d2-494a-a2f5-c68f10d09d0a
# sentence           the trend is expected to reverse as soon as ne...
# label                                                            OBJ
# solved_conflict                                                False
# Name: 1, dtype: object
# sentence_id            4076639c-aa56-4202-ae0f-9d9217f8da68
# sentence           but there is the specious point again .
# label                                                   OBJ
# solved_conflict                                       False
# Name: 2, dtype: object
# sentence_id                     b057c366-698e-419d-a284-9b16d835c64e
# sentence           he added he would not be surprised to see a ne...
# label                                                            OBJ
# solved_conflict                                                False
# Name: 3, dtype: object
# sentence_id                     a5a9645e-7850-41ba-90a2-5def725cd5b8
# sentence           not less government  you see  the same amount ...
# label                                                           SUBJ
# solved_conflict                                                False
# Name: 4, dtype: object
# sentence_id                     11c50742-4455-4653-bf9d-4810968d3ee1
# sentence           but when one expresses a timid doubt regarding...
# label                                                           SUBJ
# solved_conflict                                                False
# Name: 5, dtype: object
# sentence_id                     f593462a-6e47-43c8-a348-b95196c07f6d
# sentence           in states with shortages  it also far more dif...
# label                                                            OBJ
# solved_conflict                                                False
# Name: 6, dtype: object
# sentence_id                     1520bc61-8bc1-4e99-b4dd-4eeb15e164e7
# sentence           yet little of substance has been done for serb...
# label                                                            OBJ
# solved_conflict                                                False
# Name: 7, dtype: object
# sentence_id                     277c37a4-5bc1-4296-bf50-6ee4780a4e51
# sentence           it meant that  for the first time in the uk  t...
# label                                                            OBJ
# solved_conflict                                                False
# Name: 8, dtype: object
# sentence_id                     23f74706-0556-4eeb-90c1-041da0d8bcd0
# sentence           marko mihailović  the 29 - year - old figurehe...
# label                                                            OBJ
# solved_conflict                                                False
# Name: 9, dtype: object
# sentence_id                     a2140c86-b140-474f-8902-0f5c19b76338
# sentence           if it consolidates power into the hands of the...
# label                                                           SUBJ
# solved_conflict                                                False
# Name: 10, dtype: object
# sentence_id        7d348c76-ca27-416a-a0b8-32975447061c
# sentence                        i was just drowning .
# label                                               OBJ
# solved_conflict                                   False
# Name: 11, dtype: object
# sentence_id                     dd5a54ff-aeca-4b1a-9ec5-9abb81e806aa
# sentence           its poorhouse is a municipal colony  governed ...
# label                                                            OBJ
# solved_conflict                                                False
# Name: 12, dtype: object
# sentence_id                     cfc26110-2ffb-4310-bbe2-9ff5cd865429
# sentence           by limiting the focus of corporate boards to s...
# label                                                           SUBJ
# solved_conflict                                                False
# Name: 13, dtype: object
# sentence_id                     119313dc-9bf0-434b-8b5a-5c1f6510552c
# sentence           who so mean that he will not himself be taxed ...
# label                                                           SUBJ
# solved_conflict                                                 True
# Name: 14, dtype: object
# sentence_id                     ce81586b-3914-4d6e-811b-084e499f3eb1
# sentence           but that is both less than many analysts expec...
# label                                                            OBJ
# solved_conflict                                                False
# Name: 15, dtype: object
# sentence_id                     2fc93ca9-4ae7-458b-ae31-cd886a2346de
# sentence           democrats in congress have tried to ban  alien...
# label                                                            OBJ
# solved_conflict                                                False
# Name: 16, dtype: object
# sentence_id                     89cccb37-28bf-439b-9257-e556ecccce17
# sentence           leftists claim the perfectly good legal phrase...
# label                                                           SUBJ
# solved_conflict                                                False
# Name: 17, dtype: object
# sentence_id                     8dd8e6d4-9f73-4ced-af27-1a76425eb379
# sentence           a large number of influential far - right move...
# label                                                            OBJ
# solved_conflict                                                False
# Name: 18, dtype: object
# sentence_id                     8265740d-7224-4d52-ba1d-b95c73f91371
# sentence           with a big police presence  pride finally went...
# label                                                            OBJ
# solved_conflict                                                False
# Name: 19, dtype: object
# sentence_id                     dc1632c5-46ff-4adb-acc8-6e4b56dc0d11
# sentence           china gdp in 2023 could be more than  $ 2trn b...
# label                                                            OBJ
# solved_conflict                                                False
# Name: 20, dtype: object
# sentence_id                     0288ebe9-bd89-49b3-ba60-f1bb745b6f48
# sentence           the accused somalis donated to a variety of po...
# label                                                            OBJ
# solved_conflict                                                False
# Name: 21, dtype: object
# sentence_id                     182d73e2-3a71-43c4-acaf-e9248817766f
# sentence           but taking refuge in public credit will cause ...
# label                                                           SUBJ
# solved_conflict                                                False
# Name: 22, dtype: object
# sentence_id                     bb3f5b4e-e145-42fb-95a1-bb9d1648fea6
# sentence            normally  the majority opinion would speak fo...
# label                                                            OBJ
# solved_conflict                                                False
# Name: 23, dtype: object
# sentence_id                     246c617d-fafb-44bd-b8e6-caebb2def18f
# sentence           way out on the outskirts  the average resident...
# label                                                            OBJ
# solved_conflict                                                False
# Name: 24, dtype: object
# sentence_id                     e3fe036b-b501-40b6-976a-92cad00a7d03
# sentence           workers would be granted only one single paid ...
# label                                                            OBJ
# solved_conflict                                                False
# Name: 25, dtype: object
# sentence_id                     26596b19-6ae0-4087-ae00-98730d33dacc
# sentence           to plug budgetary holes  80 out of 111 cities ...
# label                                                            OBJ
# solved_conflict                                                False
# Name: 26, dtype: object
# sentence_id                     d9b68138-3561-4222-9364-724f49ff792f
# sentence           that state has sixty - two counties and sixty ...
# label                                                           SUBJ
# solved_conflict                                                 True
# Name: 27, dtype: object
# sentence_id                     eaebd7db-6f3d-4c70-98d6-34b225389533
# sentence           first by habit one thinks of those for which w...
# label                                                           SUBJ
# solved_conflict                                                False
# Name: 28, dtype: object
# sentence_id                     18da0aa0-dc23-4028-9505-0ee169ebcc45
# sentence            after europride went to warsaw in 2010 and ri...
# label                                                            OBJ
# solved_conflict                                                False
# Name: 29, dtype: object
# sentence_id        831f054e-4cc3-475d-b58f-c85f75900e8f
# sentence                                  or a doctor
# label                                               OBJ
# solved_conflict                                   False
# Name: 30, dtype: object
# sentence_id        5891befb-11d7-4802-91e6-170dfe2b2d5e
# sentence                        and of course  he is .
# label                                               OBJ
# solved_conflict                                   False
# Name: 31, dtype: object
# sentence_id                     2178db02-b737-4cd8-b12e-fa55f3ca76d2
# sentence           a government serious about equality and  level...
# label                                                           SUBJ
# solved_conflict                                                False
# Name: 32, dtype: object
# sentence_id        1740ae0d-8ea6-4f93-bbd5-a3275b5e8d97
# sentence                      why are teachers unhappy
# label                                               OBJ
# solved_conflict                                   False
# Name: 33, dtype: object
# sentence_id                     cfebca6b-2658-4c9a-9058-d6e198448c21
# sentence           if you are looking for a bellwether for the wo...
# label                                                           SUBJ
# solved_conflict                                                False
# Name: 34, dtype: object
# sentence_id                     920fd815-b798-4d8d-8cae-03bd50997ccd
# sentence           thoughtful proponents of stakeholder capitalis...
# label                                                            OBJ
# solved_conflict                                                False
# Name: 35, dtype: object
# sentence_id                     5ff28d29-b8f1-4b0e-a2b3-b116eefef72e
# sentence           this is the strongest case for stakeholder cap...
# label                                                           SUBJ
# solved_conflict                                                False
# Name: 36, dtype: object
# sentence_id                     55afdcb9-4f47-40b4-b1ca-7010701712e3
# sentence           the fiscal swing was more like 4 %  of gdp in ...
# label                                                            OBJ
# solved_conflict                                                False
# Name: 37, dtype: object
# sentence_id                     7fd2526a-27c2-4a91-8302-c1a0bfa420a3
# sentence           in theory  the problematic behavior parts of t...
# label                                                           SUBJ
# solved_conflict                                                False
# Name: 38, dtype: object
# sentence_id                     b662740f-a3a5-4bf5-96e5-0012c1e05338
# sentence           conservatives reject that . '  under boris joh...
# label                                                            OBJ
# solved_conflict                                                False
# Name: 39, dtype: object
# sentence_id        93a28974-cb99-4232-aca6-386033082974
# sentence                      why are teachers unhappy
# label                                               OBJ
# solved_conflict                                   False
# Name: 40, dtype: object
# sentence_id                     5d8521c0-ea65-425e-94ce-fb73ba1ec702
# sentence           it is not entirely clear how ba . 4 . 6 has em...
# label                                                            OBJ
# solved_conflict                                                False
# Name: 41, dtype: object
# sentence_id                     29493d63-8766-46d2-ba47-a7a1fc23927f
# sentence           bankers are loath to lend it any more money be...
# label                                                            OBJ
# solved_conflict                                                False
# Name: 42, dtype: object
# sentence_id                     df7e8368-c6f6-4c7d-aa46-e73a66352c06
# sentence           the event  which organisers had envisaged as a...
# label                                                           SUBJ
# solved_conflict                                                False
# Name: 43, dtype: object
# sentence_id                     54523536-da73-486d-8037-5b1465ae9236
# sentence           garina  who was there  recalls that belgrade  ...
# label                                                            OBJ
# solved_conflict                                                False
# Name: 44, dtype: object
# sentence_id                     da6f1d5b-3d8a-4e23-8d8d-e923fa62570f
# sentence           even so  the 'racist scandal' proved to be a r...
# label                                                           SUBJ
# solved_conflict                                                False
# Name: 45, dtype: object
# sentence_id                     72d5edc9-d726-4b0c-b1d8-a4570f2e2304
# sentence           but these are federal expenditures  and they h...
# label                                                            OBJ
# solved_conflict                                                False
# Name: 46, dtype: object
# sentence_id                     95bb5ed6-49b7-4e72-9b57-c9a7746e59cb
# sentence           rail workers have no sick days and a very limi...
# label                                                            OBJ
# solved_conflict                                                False
# Name: 47, dtype: object
# sentence_id                     bf13da5e-9008-48e7-81c4-49e293426093
# sentence           yulin  a city in shaanxi province  imposed a f...
# label                                                            OBJ
# solved_conflict                                                False
# Name: 48, dtype: object
# sentence_id                     7ab04b3b-9022-49b7-bece-05fcabb2e9ca
# sentence           this makes reading the reports indoctrinated p...
# label                                                           SUBJ
# solved_conflict                                                False
# Name: 49, dtype: object
# sentence_id                     5ce9f566-4d05-45bc-ba60-d43b68f3113a
# sentence           suppose they did work  the tide rising to save...
# label                                                           SUBJ
# solved_conflict                                                False
# Name: 50, dtype: object
# sentence_id                  e4e388ca-39ad-4b83-a612-a6f5a6b79678
# sentence           there an ilhan omar angle and a mecca angle .
# label                                                         OBJ
# solved_conflict                                             False
# Name: 51, dtype: object
# sentence_id        d6899df4-a50b-4344-aead-7a0d9a28a7d2
# sentence                      why are teachers unhappy
# label                                               OBJ
# solved_conflict                                   False
# Name: 52, dtype: object
# sentence_id                     598c98b7-d2af-496e-be46-e27c51b1b541
# sentence           there is yet everywhere a deficit in the publi...
# label                                                           SUBJ
# solved_conflict                                                False
# Name: 53, dtype: object
# sentence_id                     8aa7ff14-7ad3-45db-8a19-639457220e74
# sentence           the newest booster injection full of mrna tech...
# label                                                            OBJ
# solved_conflict                                                False
# Name: 54, dtype: object
# sentence_id                     5eec6fa5-d193-4062-936b-8e06a35dbeb2
# sentence            fortune  the centers for disease control and ...
# label                                                            OBJ
# solved_conflict                                                False
# Name: 55, dtype: object
# sentence_id                     44560d31-dfa3-4a2a-bfa7-15477227b1cc
# sentence           right now  the most common variant is ba . 5  ...
# label                                                            OBJ
# solved_conflict                                                False
# Name: 56, dtype: object
# sentence_id                     f5bbd316-8952-4603-8982-ab3154bd598c
# sentence           nonetheless i believe it falls short for legal...
# label                                                           SUBJ
# solved_conflict                                                False
# Name: 57, dtype: object
# sentence_id                     1cb0281c-715e-4d9e-8222-797f79a59d80
# sentence           but the white house and mainstream media will ...
# label                                                           SUBJ
# solved_conflict                                                False
# Name: 58, dtype: object
# sentence_id                     53b4439a-d1ac-4441-8f4b-a1299d2a0b7f
# sentence           nationally  the percentage of teachers quittin...
# label                                                            OBJ
# solved_conflict                                                False
# Name: 59, dtype: object
# sentence_id                     27495e51-e72b-4be9-a224-3428f6db7640
# sentence           on that day the city council adopted two resol...
# label                                                            OBJ
# solved_conflict                                                False
# Name: 60, dtype: object
# sentence_id                     f9235b9f-1e38-4706-8c1d-83e44dda3d9d
# sentence           many journalists are trying to cling to the re...
# label                                                           SUBJ
# solved_conflict                                                False
# Name: 61, dtype: object
# sentence_id                     eb89653a-376c-4f5a-b0f3-1853691b17b9
# sentence           usually  when politicians use these open  news...
# label                                                           SUBJ
# solved_conflict                                                False
# Name: 62, dtype: object
# sentence_id                     e14d1c51-0140-45f8-b234-0d29d271cec0
# sentence           the per capita cost of all government has incr...
# label                                                            OBJ
# solved_conflict                                                False
# Name: 63, dtype: object
# sentence_id                     b938e7a8-3ee2-4aff-824f-5e33b72c8f5a
# sentence           as a result  monetary easing did not translate...
# label                                                            OBJ
# solved_conflict                                                False
# Name: 64, dtype: object
# sentence_id                     a57e6c4f-427d-4ca2-b973-4ad1c4b92d72
# sentence           they have not only tolerated but given encoura...
# label                                                           SUBJ
# solved_conflict                                                 True
# Name: 65, dtype: object
# sentence_id                     19470b2e-7945-4840-bd01-e85efd8580a3
# sentence           even the regular television news was matter of...
# label                                                            OBJ
# solved_conflict                                                False
# Name: 66, dtype: object
# sentence_id                     953178f8-26ab-4433-a6e4-bb38a02ee0d7
# sentence           this year  the party lobbied for a parliamenta...
# label                                                            OBJ
# solved_conflict                                                False
# Name: 67, dtype: object
# sentence_id        c037ed99-d375-46d2-ad8d-91097a8f47d9
# sentence             is this a warning of what to come
# label                                               OBJ
# solved_conflict                                    True
# Name: 68, dtype: object
# sentence_id                   137a9445-559a-43d7-a01b-2ae71001407f
# sentence           a key element in the fraud was crying racism .
# label                                                         SUBJ
# solved_conflict                                              False
# Name: 69, dtype: object
# sentence_id                     157bf8d3-e28d-488f-9dd4-5fadcbcd2f65
# sentence           and so these ideas spread like wildfire from c...
# label                                                           SUBJ
# solved_conflict                                                False
# Name: 70, dtype: object
# sentence_id                     fbdb93fa-2f0f-461f-9557-c0a2aa9c26c5
# sentence           as of last year  california and colorado had b...
# label                                                            OBJ
# solved_conflict                                                False
# Name: 71, dtype: object
# sentence_id                     90e7d7b8-0977-4593-b8bd-b249ad21114b
# sentence           this is not a world where details of propertie...
# label                                                           SUBJ
# solved_conflict                                                False
# Name: 72, dtype: object
# sentence_id                     d936a13a-96fa-4a5b-b357-0d5564770ddf
# sentence           on paid time off and sick days  perhaps the mo...
# label                                                            OBJ
# solved_conflict                                                False
# Name: 73, dtype: object
# sentence_id                     516f1cae-e840-4a70-8569-74d2bddf1f0e
# sentence            we regard this as the tyranny of an extreme m...
# label                                                            OBJ
# solved_conflict                                                False
# Name: 74, dtype: object
# sentence_id                     f28d584f-1fcc-44cb-a893-5082a01292b4
# sentence           increasingly  as it may seem  irresistibly  we...
# label                                                           SUBJ
# solved_conflict                                                False
# Name: 75, dtype: object
# sentence_id                     96275c61-bea9-478f-a851-e57a3ab6edba
# sentence           this is a far cry from the rail unions' origin...
# label                                                            OBJ
# solved_conflict                                                False
# Name: 76, dtype: object
# sentence_id                     fe22144f-722a-42fa-a4ab-3da82f602db0
# sentence           the title was as well received as the argument...
# label                                                            OBJ
# solved_conflict                                                False
# Name: 77, dtype: object
# sentence_id                     0e67c312-1288-4300-991f-d93ccca01ba1
# sentence           when i first started writing about the rise of...
# label                                                            OBJ
# solved_conflict                                                False
# Name: 78, dtype: object
# sentence_id                     a67a08da-9bd5-4f54-9a0f-1b8bef2518f8
# sentence           white house aides worked to create contingency...
# label                                                            OBJ
# solved_conflict                                                False
# Name: 79, dtype: object
# sentence_id                     47347a7f-ae10-4365-80ed-aa2efe519c81
# sentence           for massachusetts the cost of it is nearly two...
# label                                                            OBJ
# solved_conflict                                                False
# Name: 80, dtype: object
# sentence_id                     8c880770-a393-4cc8-ba17-89cbf57432d0
# sentence           denmark  germany  and france have each seen 10...
# label                                                            OBJ
# solved_conflict                                                False
# Name: 81, dtype: object
# sentence_id                    b54752ee-3f59-409e-a93a-ae09efae1bab
# sentence           sometime the tide  of itself  will rise again .
# label                                                           OBJ
# solved_conflict                                               False
# Name: 82, dtype: object
# sentence_id                     e1d1a666-8433-4696-bc03-c7ac9d370a48
# sentence            shtfplan  according to a report by ndtv  the ...
# label                                                            OBJ
# solved_conflict                                                False
# Name: 83, dtype: object
# sentence_id                     f1735b48-b058-40d9-bb04-96904776bdfd
# sentence           some districts rejected masking requirements a...
# label                                                            OBJ
# solved_conflict                                                False
# Name: 84, dtype: object
# sentence_id                     827fb861-5a2f-4879-b20a-b06987f6c5d0
# sentence           the fda has issued new guidance for the antivi...
# label                                                            OBJ
# solved_conflict                                                False
# Name: 85, dtype: object
# sentence_id                     7f08a4ec-5a50-48ce-b543-98323e5f4dee
# sentence           no government ever surrenders power  even its ...
# label                                                           SUBJ
# solved_conflict                                                False
# Name: 86, dtype: object
# sentence_id                     ada37909-9f6e-4804-85b4-cea500f33f28
# sentence           though not all details have been released  it ...
# label                                                            OBJ
# solved_conflict                                                False
# Name: 87, dtype: object
# sentence_id                     3e9f5450-98d5-452f-8697-38f3d5f89d23
# sentence           this unique set of circumstances has brought p...
# label                                                            OBJ
# solved_conflict                                                 True
# Name: 88, dtype: object
# sentence_id                     60e92229-6920-45fa-9830-1d6a83616beb
# sentence           whatever else may go by conjecture  this will ...
# label                                                           SUBJ
# solved_conflict                                                False
# Name: 89, dtype: object
# sentence_id                     80bd9417-67d8-4fc3-8b34-54f0b22926cc
# sentence           pride organisers had remained defiant  saying ...
# label                                                            OBJ
# solved_conflict                                                False
# Name: 90, dtype: object
# sentence_id                     880b6d56-823b-434b-b511-f615ebe871f3
# sentence           it may mean to surrender them  but on the firs...
# label                                                           SUBJ
# solved_conflict                                                False
# Name: 91, dtype: object
# sentence_id                     99091e2e-e793-4c43-94c7-3c4bd3e7e97b
# sentence           these ndmps  according to the draft bill  can ...
# label                                                           SUBJ
# solved_conflict                                                False
# Name: 92, dtype: object
# sentence_id                     83434214-cccc-480c-8eb5-99ff96cced8a
# sentence            this latest rule will open our borders even m...
# label                                                            OBJ
# solved_conflict                                                False
# Name: 93, dtype: object
# sentence_id                     8ae1d488-5231-42e9-b87b-242c668b4e6a
# sentence           torrential spending by the many arms of the st...
# label                                                           SUBJ
# solved_conflict                                                False
# Name: 94, dtype: object
# sentence_id                     921a1f46-1494-4004-95ed-d26b907d3aae
# sentence           it has been a bumpy road even to this juncture .
# label                                                           SUBJ
# solved_conflict                                                False
# Name: 95, dtype: object
# sentence_id                     c2ca3827-247d-4302-971d-8054d32c73aa
# sentence           socialists believe that  if everyone cannot ha...
# label                                                            OBJ
# solved_conflict                                                 True
# Name: 96, dtype: object
# sentence_id                     58d703aa-131b-40b4-8373-0c34b86bb1c7
# sentence           vučić said he regretted it but cited a deepeni...
# label                                                            OBJ
# solved_conflict                                                False
# Name: 97, dtype: object
# sentence_id                     cb0dd788-2074-4469-a8f9-24d163db41c6
# sentence            there have been more rightwing extremists spr...
# label                                                            OBJ
# solved_conflict                                                False
# Name: 98, dtype: object
# sentence_id                     84ac387e-d7c7-4cb5-b82d-8a07a2869ce4
# sentence            the exposé  the real problem is that the new ...
# label                                                            OBJ
# solved_conflict                                                False
# Name: 99, dtype: object
# sentence_id                     56065090-3ff8-44a9-adaa-bd7617e972a9
# sentence           demands upon the public credit for social serv...
# label                                                           SUBJ
# solved_conflict                                                False
# Name: 100, dtype: object
# sentence_id                     f8f764dc-f0b1-4276-a4a2-e26c2fc774ca
# sentence           this that the cost of government shall be redu...
# label                                                           SUBJ
# solved_conflict                                                False
# Name: 101, dtype: object
# sentence_id                     7c90f8f0-b98b-4e5f-bb77-104308058d1b
# sentence           these illegal - alien lawyers will now be allo...
# label                                                           SUBJ
# solved_conflict                                                 True
# Name: 102, dtype: object
# sentence_id                     2a0a8ed6-fd9b-4ba5-862b-41ac44a117eb
# sentence           this is the great negative externality of stak...
# label                                                           SUBJ
# solved_conflict                                                False
# Name: 103, dtype: object
# sentence_id                     61c3f550-2632-4506-b539-71f37ce710da
# sentence           states are finding it hardest to retain staff ...
# label                                                            OBJ
# solved_conflict                                                False
# Name: 104, dtype: object
# sentence_id                     ff686f1c-7413-40ae-b31e-3f10c4febc52
# sentence            there will be a rise in hospitalization and m...
# label                                                            OBJ
# solved_conflict                                                False
# Name: 105, dtype: object
# sentence_id                     aa46d4c3-21a2-478d-9c72-d2091fb1c297
# sentence           the economist has called limited liability  on...
# label                                                            OBJ
# solved_conflict                                                False
# Name: 106, dtype: object
# sentence_id                     8ab997bd-c6d4-43a5-b1f6-21ae541ff3be
# sentence            our reference was to states that provide or h...
# label                                                            OBJ
# solved_conflict                                                False
# Name: 107, dtype: object
# sentence_id                     a37dd484-e3fd-454d-9076-d09eadeebf97
# sentence           caught in the culture wars  in a recent poll  ...
# label                                                            OBJ
# solved_conflict                                                False
# Name: 108, dtype: object
# sentence_id         c7cc5770-dece-4579-a479-fa7409f8bc0a
# sentence           but this week  bf . 7 surpassed it .
# label                                                OBJ
# solved_conflict                                    False
# Name: 109, dtype: object
# sentence_id                     a9e1eabe-25fc-4a6b-8e46-d948a5c1104c
# sentence           it has allowed local authorities to issue anot...
# label                                                            OBJ
# solved_conflict                                                False
# Name: 110, dtype: object
# sentence_id                     e971ffca-9618-4b14-9550-d5c7b16b4891
# sentence           there are some frauds so massively insane that...
# label                                                           SUBJ
# solved_conflict                                                False
# Name: 111, dtype: object
# sentence_id                     a6ff6961-4888-4291-b365-f81ea80a76eb
# sentence           in a statement  the white house said   the adm...
# label                                                            OBJ
# solved_conflict                                                False
# Name: 112, dtype: object
# sentence_id                     a476b7a7-98c6-4db0-8193-1c105e325c0d
# sentence           more than that  reducing the cost of governmen...
# label                                                            OBJ
# solved_conflict                                                False
# Name: 113, dtype: object
# sentence_id                     31ab5053-e58e-4ba8-8f4d-af9d1b85f96c
# sentence           boris johnson declared  levelling up' the  def...
# label                                                           SUBJ
# solved_conflict                                                False
# Name: 114, dtype: object
# sentence_id                     f5b5a680-4636-4448-9c51-a2f504f9eb73
# sentence           if it is far away from a black neighborhood  t...
# label                                                            OBJ
# solved_conflict                                                False
# Name: 115, dtype: object
# sentence_id            f0ab93fd-ded6-4210-b5bd-0bd487eb3e0e
# sentence           observe another strange bedfellowship .
# label                                                  SUBJ
# solved_conflict                                       False
# Name: 116, dtype: object
# sentence_id        91150888-3ed2-4fcd-97ff-219149a0e13d
# sentence                     yet suppose differently .
# label                                               OBJ
# solved_conflict                                   False
# Name: 117, dtype: object
# sentence_id                     933fec57-8c72-4ef0-8953-857b6e2f74fb
# sentence           there currently no evidence of a direct questi...
# label                                                           SUBJ
# solved_conflict                                                False
# Name: 118, dtype: object
# sentence_id        8a0f6e11-c4cc-471d-9687-80e71c5a3301
# sentence             china had other strings to pull .
# label                                               OBJ
# solved_conflict                                   False
# Name: 119, dtype: object
# sentence_id                     9ebd51e3-8f5a-4174-938f-1efdf3bfe85d
# sentence           the reason for the lack of any actual  levelli...
# label                                                           SUBJ
# solved_conflict                                                False
# Name: 120, dtype: object
# sentence_id                     4d21c9ea-27f0-473b-85c0-f130f3cd2e72
# sentence           the union also managed to win no increases to ...
# label                                                            OBJ
# solved_conflict                                                False
# Name: 121, dtype: object
# sentence_id                     07b28f64-dd52-4899-8ebb-50388106a869
# sentence            the same growth advantage in multiple countri...
# label                                                            OBJ
# solved_conflict                                                False
# Name: 122, dtype: object
# sentence_id                     6751566d-fc18-45e9-941a-b778beb79062
# sentence           the central mechanism of this process is the i...
# label                                                            OBJ
# solved_conflict                                                False
# Name: 123, dtype: object
# sentence_id                     534400f6-3a94-4c84-8c0d-57127f013799
# sentence           crying racism worked and at its peak  safari c...
# label                                                            OBJ
# solved_conflict                                                False
# Name: 124, dtype: object
# sentence_id                     0e752cf4-2111-44cc-ad78-e6deaeeba1c1
# sentence           despite all the talk of a postindustrial and s...
# label                                                           SUBJ
# solved_conflict                                                 True
# Name: 125, dtype: object
# sentence_id                     200ae773-1d33-41da-95db-4fda10929cf8
# sentence           observe that in time of prosperity government ...
# label                                                           SUBJ
# solved_conflict                                                False
# Name: 126, dtype: object
# sentence_id        4fecb402-b8d4-45fe-842e-babddbe9aa1b
# sentence              nevertheless  they are limited .
# label                                               OBJ
# solved_conflict                                   False
# Name: 127, dtype: object
# sentence_id                     08834a92-4384-4591-bed6-5090a828eb9b
# sentence           indeed  one of the main concerns of the commit...
# label                                                            OBJ
# solved_conflict                                                False
# Name: 128, dtype: object
# sentence_id                     9c0ba5db-63c9-4c46-b938-7329a7e3be15
# sentence           stakeholder capitalism refers or at least used...
# label                                                            OBJ
# solved_conflict                                                False
# Name: 129, dtype: object
# sentence_id                     76803cdc-afd6-47fa-98aa-a7ac17ec6fcc
# sentence           planning  like the nhs  is one of the few area...
# label                                                            OBJ
# solved_conflict                                                False
# Name: 130, dtype: object
# sentence_id        1e998db4-55ec-4ada-af94-7b451434fcb9
# sentence                is this predictive programming
# label                                              SUBJ
# solved_conflict                                   False
# Name: 131, dtype: object
# sentence_id                     099ebe96-a98c-4e5c-b9ad-723f19ab434c
# sentence           ba . 2 . 75 still predicted to overtake in man...
# label                                                            OBJ
# solved_conflict                                                False
# Name: 132, dtype: object
# sentence_id                     7386c1a8-bfaa-40f4-9cb6-4b9cd43cc330
# sentence           two children in every nine are so far handicap...
# label                                                            OBJ
# solved_conflict                                                False
# Name: 133, dtype: object
# sentence_id                     c4643a8a-ad73-41df-a950-8f54c7141b02
# sentence           it ran over the rondo neighborhood which was t...
# label                                                            OBJ
# solved_conflict                                                False
# Name: 134, dtype: object
# sentence_id                    b349e288-3f96-4174-93c2-962862426f47
# sentence           some politicians came forward to back them up .
# label                                                           OBJ
# solved_conflict                                               False
# Name: 135, dtype: object
# sentence_id                     ad238ccb-6a49-4e20-ba92-626b605e2f15
# sentence           but with the public credit of a nation  it was...
# label                                                            OBJ
# solved_conflict                                                False
# Name: 136, dtype: object
# sentence_id                     0e0143d4-cbb1-41ee-8219-14fbc7fed78c
# sentence           kristine garina  the latvian president of the ...
# label                                                            OBJ
# solved_conflict                                                False
# Name: 137, dtype: object
# sentence_id                     dfa1b296-91b3-45b9-9800-b0bea1f62dae
# sentence           blacks tend to live near the center of cities ...
# label                                                            OBJ
# solved_conflict                                                 True
# Name: 138, dtype: object
# sentence_id                     fa7a13a7-619c-452b-87d8-fbe81059b130
# sentence           the principal reason  from the point of view o...
# label                                                            OBJ
# solved_conflict                                                False
# Name: 139, dtype: object
# sentence_id                     27b8f9ba-9abf-4257-b92d-062338333046
# sentence           stakeholder capitalism poisons democracy and p...
# label                                                           SUBJ
# solved_conflict                                                False
# Name: 140, dtype: object
# sentence_id                     0156b6cd-b7db-4180-8510-5fd9e2b64496
# sentence           there are two things in particular that show p...
# label                                                            OBJ
# solved_conflict                                                False
# Name: 141, dtype: object
# sentence_id                     992e2e04-1374-4fee-b888-f0bb95700e76
# sentence           by economy  by the elimination of graft and ne...
# label                                                            OBJ
# solved_conflict                                                False
# Name: 142, dtype: object
# sentence_id                     97fb9359-cbd3-4df2-8e53-d098e9a00fa8
# sentence           and while local far - right activists appear t...
# label                                                           SUBJ
# solved_conflict                                                False
# Name: 143, dtype: object
# sentence_id                     8e7acea0-9771-4e03-834d-70fa10945638
# sentence            visibility has increased   but that progress ...
# label                                                            OBJ
# solved_conflict                                                False
# Name: 144, dtype: object
# sentence_id                     dcb55612-bc0c-4ddf-bb9d-9851e7436dd8
# sentence           pic . twitter . com thb42hdbho    tom wenselee...
# label                                                            OBJ
# solved_conflict                                                False
# Name: 145, dtype: object
# sentence_id                     5e63fc65-41f2-49aa-a593-45344a9f9c6c
# sentence           still  many of the nation 3 . 1 million public...
# label                                                           SUBJ
# solved_conflict                                                 True
# Name: 146, dtype: object
# sentence_id                     b07f5f9e-afd1-42a8-a473-51b3e35eef03
# sentence           president hoover says   i have no taste for an...
# label                                                            OBJ
# solved_conflict                                                False
# Name: 147, dtype: object
# sentence_id                     72f0579d-0e4f-4787-9cee-ea490692cbd9
# sentence           the planning system initial institution was ai...
# label                                                            OBJ
# solved_conflict                                                False
# Name: 148, dtype: object
# sentence_id                     040c9f23-a7e8-46e6-b8a0-630c306cfd8b
# sentence           for months scientists watched ba . 2 . 75  dub...
# label                                                            OBJ
# solved_conflict                                                False
# Name: 149, dtype: object
# sentence_id                     dfa90669-ed82-482d-a471-236228cf2864
# sentence           such a boss as this now commands the support  ...
# label                                                           SUBJ
# solved_conflict                                                 True
# Name: 150, dtype: object
# sentence_id        df1c5aba-a52a-44a5-b8ad-6a9f28ae476f
# sentence                              absolutely not .
# label                                               OBJ
# solved_conflict                                   False
# Name: 151, dtype: object
# sentence_id                     84740b52-7bc2-4c0c-95d5-a24b8ec3c299
# sentence           the suit is the result of james' years - long ...
# label                                                            OBJ
# solved_conflict                                                False
# Name: 152, dtype: object
# sentence_id                     729c8fb9-aa88-4cfd-b92b-80a005ed0e32
# sentence           when the money was denied  feeding our future ...
# label                                                            OBJ
# solved_conflict                                                False
# Name: 153, dtype: object
# sentence_id                     a2bda341-c37a-466a-be16-89f6eff5fe67
# sentence           years of talk about missions   left behind' pl...
# label                                                           SUBJ
# solved_conflict                                                False
# Name: 154, dtype: object
# sentence_id                     82cd8a8c-0cd5-4fb2-b15f-0c68284e5f92
# sentence           though some journalists with knowledge of the ...
# label                                                            OBJ
# solved_conflict                                                False
# Name: 155, dtype: object
# sentence_id                     c7c041a6-69a3-4ca3-9048-217e7c8f0abc
# sentence           the same spirit that moves old - age pensions ...
# label                                                            OBJ
# solved_conflict                                                False
# Name: 156, dtype: object
# sentence_id                     0c76766f-84c8-4013-b6bc-194a12a8b601
# sentence           china leaders may be seeking to avoid the past...
# label                                                            OBJ
# solved_conflict                                                False
# Name: 157, dtype: object
# sentence_id                     f061af8f-58c0-4280-bc59-eada992aeab6
# sentence           but all that has gone out of the window since ...
# label                                                           SUBJ
# solved_conflict                                                 True
# Name: 158, dtype: object
# sentence_id                     188b82f8-df67-4806-a4f3-8507b6ca495a
# sentence           in the early hours of thursday morning  the wh...
# label                                                            OBJ
# solved_conflict                                                False
# Name: 159, dtype: object
# sentence_id                     fda1bd31-e0ae-4d90-b6e5-2749cc7430bb
# sentence           at the same time  the struggle to make up for ...
# label                                                            OBJ
# solved_conflict                                                False
# Name: 160, dtype: object
# sentence_id                     b29b7013-a58b-4cf3-aeab-4a2397fea6e9
# sentence           somewhere in - between is an optimum point  al...
# label                                                           SUBJ
# solved_conflict                                                False
# Name: 161, dtype: object
# sentence_id                     33c94ab6-3c0d-440b-a4e1-3b22698b5963
# ...
# label                                                            OBJ
# solved_conflict                                                False
# Name: 885, dtype: object
# sentence_id                     e5d06c08-ecc9-4ec4-a3a5-bae5914731b7
# sentence           however  getting annoyed at the language in wh...
# label                                                           SUBJ
# solved_conflict                                                False
# Name: 886, dtype: object
# sentence_id                     1b422f02-948f-43c0-a39e-6ec6afe1ac4f
# sentence           for example  chinese immigrants no doubt deser...
# label                                                           SUBJ
# solved_conflict                                                False
# Name: 887, dtype: object
# sentence_id                     17bb1ca0-2a4b-4415-b31c-3ac8d7df0c1d
# sentence           he had links with planned parenthood and with ...
# label                                                            OBJ
# solved_conflict                                                False
# Name: 888, dtype: object
# sentence_id                     aeaf21fb-6a10-4258-95ee-9806ed17f57a
# sentence           it hard for this book to go completely wrong  ...
# label                                                            OBJ
# solved_conflict                                                False
# Name: 889, dtype: object
# sentence_id        c585cac5-c985-41f2-9596-a9f1ecc51ea0
# sentence             but it needs to go much further .
# label                                              SUBJ
# solved_conflict                                    True
# Name: 890, dtype: object
# sentence_id                     61f81c00-d0c9-4a7f-a938-281d53ad912d
# sentence           in part this is because the deleterious situat...
# label                                                           SUBJ
# solved_conflict                                                False
# Name: 891, dtype: object
# sentence_id                     c7ecb649-8ff0-41ed-96e2-954fb64e72b9
# sentence           beyond all the double talk and cant  that what...
# label                                                           SUBJ
# solved_conflict                                                 True
# Name: 892, dtype: object
# sentence_id                     baa210af-4dc2-4b29-a8da-88987d361377
# sentence           the last line of this nr piece was  mr .  brim...
# label                                                            OBJ
# solved_conflict                                                False
# Name: 893, dtype: object
# sentence_id                     e880f523-f826-4128-b3c9-da98747af8d6
# sentence           once her rancid twitter feed started to get me...
# label                                                           SUBJ
# solved_conflict                                                False
# Name: 894, dtype: object
# sentence_id                     efb0b395-f6b3-4493-84e5-7500d1ab040e
# sentence           republicans are prioritizing critical race the...
# label                                                            OBJ
# solved_conflict                                                False
# Name: 895, dtype: object
# sentence_id                     deb21eeb-86a2-4d83-8b72-bb3c74c218ed
# sentence            jf  i wrote in march 2020 that  a number of i...
# label                                                           SUBJ
# solved_conflict                                                False
# Name: 896, dtype: object
# sentence_id                     7b7085cb-a71c-44b7-8cc0-1823ec89ca05
# sentence           it also true that mass immigration  which was ...
# label                                                           SUBJ
# solved_conflict                                                False
# Name: 897, dtype: object
# sentence_id                     94b23e07-4978-4d12-9efe-9fcdcd59b1d1
# sentence           the single issue that overcame all others  mr ...
# label                                                           SUBJ
# solved_conflict                                                 True
# Name: 898, dtype: object
# sentence_id                     b5261758-20c9-4afd-b4ca-cfa26f3418e5
# sentence           if the new york times intends to reverse a gen...
# label                                                           SUBJ
# solved_conflict                                                False
# Name: 899, dtype: object
# sentence_id                     56a1c548-f084-465c-a55c-02cb874d079b
# sentence           it is frankly a handbook  almost a work in pro...
# label                                                           SUBJ
# solved_conflict                                                False
# Name: 900, dtype: object
# sentence_id                     7d43f1e4-cc11-4015-8de0-c881f970d90a
# sentence           wing is also the co - author of several leftis...
# label                                                            OBJ
# solved_conflict                                                False
# Name: 901, dtype: object
# sentence_id                     6edaafad-75bf-41ef-9b6f-1752aadd2c2d
# sentence           not least in our immediate moment  as normal l...
# label                                                           SUBJ
# solved_conflict                                                False
# Name: 902, dtype: object
# sentence_id                     57221b29-dbf7-4ec8-b6c0-865da935d192
# sentence           instead  it is distracted by fantasies of raci...
# label                                                           SUBJ
# solved_conflict                                                False
# Name: 903, dtype: object
# sentence_id                     50b02b91-1016-44a9-b178-7462567d1d18
# sentence           about as dull and conventional as you would ex...
# label                                                           SUBJ
# solved_conflict                                                False
# Name: 904, dtype: object
# sentence_id                     883d3cb5-49b5-481a-8b53-ae8d42080d35
# sentence           the most recent figures point to close to 5000...
# label                                                            OBJ
# solved_conflict                                                False
# Name: 905, dtype: object
# sentence_id                     94da768a-37bb-4685-bbec-0736886983a7
# sentence           on nearly every issue dealing with immigration...
# label                                                            OBJ
# solved_conflict                                                False
# Name: 906, dtype: object
# sentence_id                     0a4e3373-4e5f-4201-bf65-195e49b8f028
# sentence           population growth has its blind boosters  on w...
# label                                                           SUBJ
# solved_conflict                                                False
# Name: 907, dtype: object
# sentence_id                     0ff59567-45ef-41fd-a74e-622283a4d658
# sentence           the gop must do much more to show it the party...
# label                                                           SUBJ
# solved_conflict                                                False
# Name: 908, dtype: object
# sentence_id                     e645d739-2952-4b0a-906a-13193136e567
# sentence           all of this amid falling pay  the most recent ...
# label                                                            OBJ
# solved_conflict                                                False
# Name: 909, dtype: object
# sentence_id            8f14010b-fff9-4964-9020-77b81ca75195
# sentence           we would have been happy to buy them .
# label                                                   OBJ
# solved_conflict                                       False
# Name: 910, dtype: object
# sentence_id                     4dde2fd9-844d-4a82-972d-ef475f1735a8
# sentence           now  this angry  self - righteous racist overs...
# label                                                           SUBJ
# solved_conflict                                                False
# Name: 911, dtype: object
# sentence_id                     a7694e1b-0cf4-43f8-b0d7-6079dccaa707
# sentence           anti - white hatred defines the democratic coa...
# label                                                           SUBJ
# solved_conflict                                                False
# Name: 912, dtype: object
# sentence_id                     5b909e36-4806-45e5-9c6d-6b096c030169
# sentence           on current projections  absent government acti...
# label                                                            OBJ
# solved_conflict                                                False
# Name: 913, dtype: object
# sentence_id                     836d171f-3262-47d4-9552-447704aebdac
# sentence           there are indeed cases of societies that have ...
# label                                                            OBJ
# solved_conflict                                                False
# Name: 914, dtype: object
# sentence_id                     e9f3fd62-9913-4179-8dbb-02bf9c59fc86
# sentence           the anti - crt messaging turned them out in re...
# label                                                            OBJ
# solved_conflict                                                False
# Name: 915, dtype: object
# sentence_id                     82eadee0-37f9-4a72-a5a0-1bbc3c1fd3f0
# sentence           stephen maturin  a key character  had only hea...
# label                                                            OBJ
# solved_conflict                                                False
# Name: 916, dtype: object
# sentence_id                     a54c28bd-bd04-40b9-b9e1-325b806d9b99
# sentence           in denmark  the government  alongside supporti...
# label                                                            OBJ
# solved_conflict                                                False
# Name: 917, dtype: object
# sentence_id                     653560f1-9724-4b19-9b54-5a629c70f988
# sentence           here a larger version of that chart above   ei...
# label                                                            OBJ
# solved_conflict                                                False
# Name: 918, dtype: object
# sentence_id                     d2e86ec8-b81d-4cfb-a2ec-b562fed6bd90
# sentence           as is often the case  when assessing political...
# label                                                           SUBJ
# solved_conflict                                                 True
# Name: 919, dtype: object
# sentence_id                     413b57cf-3daa-4389-ac83-448163316f07
# sentence           for intelligence  there is nothing like a keen...
# label                                                           SUBJ
# solved_conflict                                                False
# Name: 920, dtype: object
# sentence_id                     676d7dfd-f9d9-42fd-9b00-2165f4576cd7
# sentence           these issues include punishing sanctuary citie...
# label                                                            OBJ
# solved_conflict                                                False
# Name: 921, dtype: object
# sentence_id                     4332344b-4218-4854-84b5-0aee517d5b85
# sentence           they fret that republicans are gasp embracing ...
# label                                                           SUBJ
# solved_conflict                                                False
# Name: 922, dtype: object
# sentence_id                     d30b2906-4fc9-468e-af83-ab845c3c1543
# sentence           assuming  that is  that environmentalists want...
# label                                                            OBJ
# solved_conflict                                                False
# Name: 923, dtype: object
# sentence_id                     c273aaad-2ddb-40c9-b22f-b4d062aa1ea0
# sentence           partly this is because of deeply deceptive adv...
# label                                                           SUBJ
# solved_conflict                                                False
# Name: 924, dtype: object
# sentence_id                     4b236b0d-34e8-4f0c-9a95-df7a461b53c7
# sentence           my favorite  mr .  roberts throw - away line t...
# label                                                           SUBJ
# solved_conflict                                                False
# Name: 925, dtype: object
# sentence_id                     1ccb946b-24a5-4d85-82e7-e0816b81011a
# sentence           he is simultaneously a practicing eye surgeon ...
# label                                                           SUBJ
# solved_conflict                                                False
# Name: 926, dtype: object
# sentence_id           8d6bf3e4-b30f-4037-ad45-77dd23cdac9d
# sentence           it the smart and natural thing to do .
# label                                                 SUBJ
# solved_conflict                                      False
# Name: 927, dtype: object
# sentence_id                     37a6f1fa-c4ce-4666-84c1-931da3b0ee06
# sentence           they want white kids to learn to hate themselv...
# label                                                           SUBJ
# solved_conflict                                                False
# Name: 928, dtype: object
# sentence_id                     e880f0f6-7e20-4596-ad2b-1f854904fc65
# sentence           dodea director thomas brady said   kelisa wing...
# label                                                           SUBJ
# solved_conflict                                                False
# Name: 929, dtype: object
# sentence_id                     9f04cac5-4551-4edb-8da2-328d992c0a73
# sentence           but of course  that did not mean 300 million a...
# label                                                            OBJ
# solved_conflict                                                False
# Name: 930, dtype: object
# sentence_id                     47c97b8e-1821-4b8c-87b1-19251971d6ca
# sentence           while other countries bring in rent freezes an...
# label                                                           SUBJ
# solved_conflict                                                False
# Name: 931, dtype: object
# sentence_id                     52a8fc30-405c-49e0-921a-d159f4f844cc
# sentence           donald trump  says wing  is the  whole  almost...
# label                                                            OBJ
# solved_conflict                                                False
# Name: 932, dtype: object
# sentence_id                     4de73031-86d8-4c9a-8783-314799e99ed8
# sentence           as has been pointed out elsewhere  the cost of...
# label                                                            OBJ
# solved_conflict                                                False
# Name: 933, dtype: object
# sentence_id                     603156df-c01c-4d9a-888b-7335793475f8
# sentence            if you are a white guy  tough luck   texas se...
# label                                                            OBJ
# solved_conflict                                                False
# Name: 934, dtype: object
# sentence_id                     e74aa315-54ac-42e4-824a-daa4037c08b7
# sentence           yet no environmentalist hoping to influence no...
# label                                                           SUBJ
# solved_conflict                                                 True
# Name: 935, dtype: object
# sentence_id                    4d87c1ea-9983-41c9-bae3-0b34a98f8036
# sentence           funny thing  the msm is at least partly right .
# label                                                          SUBJ
# solved_conflict                                               False
# Name: 936, dtype: object
# sentence_id        e485f164-36b3-492d-b999-7f5bcafa1db4
# sentence                             he died in 2019 .
# label                                               OBJ
# solved_conflict                                   False
# Name: 937, dtype: object
# sentence_id                     48bbaf14-d23a-49ec-a565-4baf9acd1b75
# sentence           but in the kingdom of the blind  or deliberate...
# label                                                           SUBJ
# solved_conflict                                                False
# Name: 938, dtype: object

# %% [markdown]
# ### Apply lemmatization

# %%
def lemmatize_sentence_spacy(sentence):
    # Load the English language model in spaCy
    nlp = spacy.load('en_core_web_sm')

    # Create a Doc object for the input sentence
    doc = nlp(sentence)

    # Lemmatize each token and join them back into a sentence
    lemmatized_sentence = ' '.join([token.lemma_ for token in doc])

    return lemmatized_sentence

# %%
data["sentence"] = data["sentence"].apply(lemmatize_sentence_spacy)

# %% [markdown]
# ### Remove stopwords

# %%
def remove_stopwords_from_sentence(sentence):
    tokens = nltk.word_tokenize(sentence)

    stop_words = set(stopwords.words('english'))

    filtered_tokens = [word for word in tokens if word.lower() not in stop_words]

    sentence_without_stopwords = ' '.join(filtered_tokens)

    return sentence_without_stopwords

# %%
data["sentence"] = data["sentence"].apply(remove_stopwords_from_sentence)

# %%
#Final output after preprocessing
data[:5]
# Out:
#                             sentence_id  \
# 0  b9e1635a-72aa-467f-86d6-f56ef09f62c3
# 1  f99b5143-70d2-494a-a2f5-c68f10d09d0a
# 2  4076639c-aa56-4202-ae0f-9d9217f8da68
# 3  b057c366-698e-419d-a284-9b16d835c64e
# 4  a5a9645e-7850-41ba-90a2-5def725cd5b8
#
#                                             sentence label  solved_conflict
# 0                 go day lead world recession - bust  SUBJ             True
# 1             trend expect reverse soon next month .   OBJ            False
# 2                                   specious point .   OBJ            False
# 3  add would surprised see new variant altogether...   OBJ            False
# 4  less government see amount government less mon...  SUBJ            False

# %% [markdown]
# ### Create binary labels and remove "solved_conflict" column
#
# Here, all labels that are "SUBJ" in column "label" are changed to 1 and "OBJ" are changed to 0. Additionally, the "solved_conflict" column is additional information that is not required. Thus, it is removed

# %%
data['label'] = data['label'].replace({'SUBJ': 1, 'OBJ': 0})
data = data.drop('solved_conflict', axis=1)

# %%
data[:5]
# Out:
#                             sentence_id  \
# 0  b9e1635a-72aa-467f-86d6-f56ef09f62c3
# 1  f99b5143-70d2-494a-a2f5-c68f10d09d0a
# 2  4076639c-aa56-4202-ae0f-9d9217f8da68
# 3  b057c366-698e-419d-a284-9b16d835c64e
# 4  a5a9645e-7850-41ba-90a2-5def725cd5b8
#
#                                             sentence  label
# 0                 go day lead world recession - bust      1
# 1             trend expect reverse soon next month .      0
# 2                                   specious point .      0
# 3  add would surprised see new variant altogether...      0
# 4  less government see amount government less mon...      1

# %% [markdown]
# ## Creating a data split of train, val and test

# %%
num_rows = len(data)
random.seed(42)
#FIX: Issue with appending obj and subj

#Isolating all rows containing OBJ and SUBJ to ensure an equal split of both in train, test and val
obj = data.loc[data['label'] == 0]
subj = data.loc[data['label'] == 1]

train_size_obj = int(0.8*len(obj))
train_size_subj = int(0.8*len(subj))
val_size_obj = int(0.1*len(obj))
val_size_subj = int(0.1*len(subj))

train_obj = obj.iloc[:train_size_obj, :]
val_obj = obj.iloc[train_size_obj: train_size_obj + val_size_obj, :]
test_obj = obj.iloc[train_size_obj + val_size_obj:, :]
train_subj = subj.iloc[:train_size_subj, :]
val_subj = subj.iloc[train_size_subj: train_size_subj + val_size_subj, :]
test_subj = subj.iloc[train_size_subj + val_size_subj:, :]

train = pd.concat([train_obj, train_subj])
val = pd.concat([val_obj, val_subj])
test = pd.concat([test_obj, test_subj])

train = train.sample(frac=1, random_state=42)
val = val.sample(frac=1, random_state=42)
test = test.sample(frac=1, random_state=42)

# Save each split into separate CSV files
train.to_csv(os.path.join(PATH, 'train.csv'), index=False)
val.to_csv(os.path.join(PATH, 'val.csv'), index=False)
test.to_csv(os.path.join(PATH, 'test.csv'), index=False)

# %%
print(f"Number of lines in the training set: {len(train)}")
print(f"Number of lines in the validation set: {len(val)}")
print(f"Number of lines in the testing set: {len(test)}")
# Out:
# Number of lines in the training set: 750
# Number of lines in the validation set: 93
# Number of lines in the testing set: 96

# %%
train.head(5)
# Out:
#                               sentence_id  \
# 120  9ebd51e3-8f5a-4174-938f-1efdf3bfe85d
# 572  99d0ce3f-dcbe-4ac7-bb1d-8c257c01d675
# 207  c46b44ec-86be-488b-87b4-4bb41e9136db
# 393  bba8e3f8-129a-409c-a00b-21e9a6f7de4b
# 475  05d269a7-9c64-4d77-9aff-dc77bdbaad4a
#
#                                               sentence  label
# 120  reason lack actual levelling ' quite clear peo...      1
# 572  reason protest lightly use public credit save ...      0
# 207  new england journal medicine study prove effec...      0
# 393  biden administration predict nearly 100 millio...      0
# 475  movement movement within government independen...      0

# %%
val.head(5)
# Out:
#                               sentence_id  \
# 784  2fa6e5cc-155a-40c5-b973-9a2b878bd01e
# 756  843e214f-9632-4357-a9dd-38512cdd30f5
# 809  d1b89811-6cb8-4f0f-a475-aea571919863
# 835  47ae6294-fab1-42d5-b23b-28ac7b4ee1fe
# 729  e39ee0e2-d109-4ec2-b9c4-eca24a00e007
#
#                                               sentence  label
# 784  argue reason corporate law codifie shareholder...      0
# 756  city assume new obligation write lend upson di...      0
# 809  agreement still need ratify member process pla...      0
# 835   may faith human inventiveness prevail long run .      1
# 729                                             hear .      0

# %%
test.head(5)
# Out:
#                               sentence_id  \
# 908  0ff59567-45ef-41fd-a74e-622283a4d658
# 903  57221b29-dbf7-4ec8-b6c0-865da935d192
# 898  94b23e07-4978-4d12-9efe-9fcdcd59b1d1
# 936  4d87c1ea-9983-41c9-bae3-0b34a98f8036
# 878  7636d762-d89f-4e40-b802-9ff9686ed265
#
#                                               sentence  label
# 908  gop must much show party white americans aka p...      1
# 903  instead distract fantasy racial discrimination...      1
# 898  single issue overcome mr . buchanan criticism ...      1
# 936               funny thing msm least partly right .      1
# 878  half social housing resident rely credit buy -...      0
